# %%
# positional and keyword argements

# %%
def greetings(greeting = 'Hello', name = 'John'):
    print(greeting + ', ' + name)

# %%
greetings()
# Out:
# Hello, John

# %%
greetings('Hi')
# Out:
# Hi, John

# %%
greetings('Hi', 'Jane')
# Out:
# Hi, Jane

# %%
# keyword argument

# %%
greetings(name='Paul')
# Out:
# Hello, Paul

# %%
greetings(greeting = 'Hi')
# Out:
# Hi, John

# %%
greetings(name = 'Paul', greeting = 'Hi')
# Out:
# Hi, Paul

# %%
# Experimental Studies

# %%
from time import time
from random import random

# %%
L = [random() for i in range(1000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 0.29175424575805664

# %%
L = [random() for i in range(10000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 5.463038921356201

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

n = []
t = []
for N in [2 ** k for k in range(15, 25)]:
    L = [random() for i in range(N)]
    start_time = time()
    end_time = time()
    elapsed_time = end_time - start_time
    n.append(N)
    t.append(elapsed_time)
    print(N, elapsed_time)
plt.plot(n, t, 'x-')
# Out:
# 32768 0.00787496566772461
# 65536 0.013165950775146484
# 131072 0.03258395195007324
# 262144 0.07182693481445312
# 524288 0.14997196197509766
# 1048576 0.46042680740356445
# 2097152 0.8540029525756836
# 4194304 1.7408840656280518
# 8388608 4.263108968734741
# 16777216 8.776694059371948
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

# %%
def prefix_average1(S):
    n = len(S)
    A = [0] * n
    for j in range(n):
        total = 0
        for i in range(j + 1):
            total += S[i]
        A[j] = total / (j + 1)
    return A

# %%
def prefix_average3(S):
    n = len(S)
    A = [0] * n
    total = 0
    for j in range(n):
        total += S[j]
        A[j] = total / (j + 1)
    return A

# %%
L = [1,2,3]

# %%
prefix_average1(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
prefix_average3(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
n = []
t1 = []
t3 = []
for N in [2 ** k for k in range(12, 16)]:
    L = [random() for i in range(N)]
    start_time = time()
    A1 = prefix_average1(L)
    end_time = time()
    elapsed_time1 = end_time - start_time
    start_time = time()
    A3 = prefix_average3(L)
    end_time = time()
    elapsed_time3 = end_time - start_time
    n.append(N)
    t1.append(elapsed_time1)
    t3.append(elapsed_time3)
    print(N, elapsed_time1, elapsed_time3)

plt.plot(n,t1,'x-')
plt.plot(n,t3,'o-')
# Out:
# 4096 0.6067659854888916 0.0007200241088867188
# 8192 2.4626989364624023 0.0013599395751953125
# 16384 9.467046737670898 0.0027570724487304688
# 32768 38.04367685317993 0.0052890777587890625
# <img src="data:image/png;base64,..." width="640">
