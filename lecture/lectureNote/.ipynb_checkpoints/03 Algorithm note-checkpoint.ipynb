# %%
# positional and keyword arguments

# %%
def greetings(greeting = 'Hello', name = 'kyle'):
    print(greeting + ', ' + name)

# %%
greetings()
# Out:
# Hello, kyle

# %%
greetings('Hi')
# Out:
# Hi, kyle

# %%
greetings('HI', 'Jane')
# Out:
# HI, Jane

# %%
# keyword argument

# %%
greetings(name = 'Paul')
# Out:
# Hello, Paul

# %%
greetings(greeting = 'Hi')
# Out:
# Hi, kyle

# %%
greetings(name = 'Paul', greeting = 'Hi')
# Out:
# Hi, Paul

# %%
# Experimental Studies

# %%
from time import time
from random import random

# %%
L = [random() for i in range(1000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 0.22705411911010742

# %%
L = [random() for i in range(10000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 3.63779616355896

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

n = []
t = []
for N in [2 ** k for k in range(15, 25)]:
    L = [random() for i in range(N)]
    start_time = time()
    L.sort()
    end_time = time()
    elapsed_time = end_time - start_time
    n.append(N)
    t.append(elapsed_time)
    print(N, elapsed_time)
plt.plot(n, t, 'x-')
# Out:
# 32768 0.006699085235595703
# 65536 0.013833045959472656
# 131072 0.022095918655395508
# 262144 0.0470128059387207
# 524288 0.1121668815612793
# 1048576 0.25574803352355957
# 2097152 0.6111629009246826
# 4194304 1.3204429149627686
# 8388608 2.947767972946167
# 16777216 6.67261004447937
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

# %%
def prefix_average1(S):
    n = len(S)
    A = [0] * n
    for j in range(n):
        total = 0
        for i in range(j + 1):
            total += S[i]
        A[j] = total / (j + 1)
    return A

# %%
def prefix_average3(S):
    n = len(S)
    A = [0] * n
    total = 0
    for j in range(n):
        total += S[j]
        A[j] = total / (j+1)
    return A

# %%
L = [1,2,3]

# %%
prefix_average1(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
prefix_average3(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
n = []
t1 = []
t3 = []
for N in [2 ** k for k in range(12, 16)]:
    L = [random() for i in range(N)]
    start_time = time()
    A1 = prefix_average1(L)
    end_time = time()
    elapsed_time1 = end_time - start_time
    start_time = time()
    A3 = prefix_average3(L)
    end_time = time()
    elapsed_time3 = end_time - start_time
    n.append(N)
    t1.append(elapsed_time1)
    t3.append(elapsed_time3)
    print(N, elapsed_time1, elapsed_time3)
    
plt.plot(n, t1, 'x-')
plt.plot(n, t3, 'o-')
# Out:
# 4096 0.48308706283569336 0.0005178451538085938
# 8192 1.9233663082122803 0.0012218952178955078
# 16384 7.65146803855896 0.0022802352905273438
# 32768 30.226159811019897 0.004561901092529297
# <img src="data:image/png;base64,..." width="639.9999861283738">
