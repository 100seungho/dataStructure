# %%
# positional and keyword argements

# %%
def greetings(greeting = 'Hello', name = 'John'):
    print(greeting + ', ' + name)

# %%
greetings()
# Out:
# Hello, John

# %%
greetings('Hi')
# Out:
# Hi, John

# %%
greetings('Hi', 'Jane')
# Out:
# Hi, Jane

# %%
# keyword argument

# %%
greetings(name='Paul')
# Out:
# Hello, Paul

# %%
greetings(greeting = 'Hi')
# Out:
# Hi, John

# %%
greetings(name = 'Paul', greeting = 'Hi')
# Out:
# Hi, Paul

# %%
# Experimental Studies

# %%
from time import time
from random import random

# %%
L = [random() for i in range(1000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 0.2908754348754883

# %%
L = [random() for i in range(10000000)]
start_time = time()
L.sort()
end_time = time()
elapsed_time = end_time - start_time
print(elapsed_time)
# Out:
# 4.100536346435547

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

n = []
t = []
for N in [2 ** k for k in range(15, 25)]:
    L = [random() for i in range(N)]
    start_time = time()
    L.sort()
    end_time = time()
    elapsed_time = end_time - start_time
    n.append(N)
    t.append(elapsed_time)
    print(N, elapsed_time)
plt.plot(n, t, 'x-')
# Out:
# 32768 0.004996299743652344
# 65536 0.013973236083984375
# 131072 0.0279848575592041
# 262144 0.06895971298217773
# 524288 0.13694214820861816
# 1048576 0.33861684799194336
# 2097152 0.7500050067901611
# 4194304 1.5722622871398926
# 8388608 3.358635187149048
# 16777216 7.386797904968262
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from time import time
from random import random
import matplotlib.pyplot as plt

# %%
def prefix_average1(S):
    n = len(S)
    A = [0] * n
    for j in range(n):
        total = 0
        for i in range(j + 1):
            total += S[i]
        A[j] = total / (j + 1)
    return A

# %%
def prefix_average3(S):
    n = len(S)
    A = [0] * n
    total = 0
    for j in range(n):
        total += S[j]
        A[j] = total / (j + 1)
    return A

# %%
L = [1,2,3]

# %%
prefix_average1(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
prefix_average3(L)
# Out:
# [1.0, 1.5, 2.0]

# %%
n = []
t1 = []
t3 = []
for N in [2 ** k for k in range(12, 16)]:
    L = [random() for i in range(N)]
    start_time = time()
    A1 = prefix_average1(L)
    end_time = time()
    elapsed_time1 = end_time - start_time
    start_time = time()
    A3 = prefix_average3(L)
    end_time = time()
    elapsed_time3 = end_time - start_time
    n.append(N)
    t1.append(elapsed_time1)
    t3.append(elapsed_time3)
    print(N, elapsed_time1, elapsed_time3)

plt.plot(n,t1,'x-')
plt.plot(n,t3,'o-')
# Out:
# 4096 0.5303897857666016 0.0019991397857666016
# 8192 2.1184792518615723 0.0009999275207519531
# 16384 8.623977184295654 0.0029981136322021484
# 32768 34.35733366012573 0.0059969425201416016
# <img src="data:image/png;base64,..." width="640">
