# %% [markdown]
# # Assignment 9
# ## Problem 1.
# What does each `remove_min` call return within the following sequence of priority queue ADT methods:
#
# ```add(5,A), add(4,B), add(7,F), add(1,D), remove_min( ), add(3,J), add(6,L), remove_min(), remove_min(), add(8,G), remove_min(), add(2,H), remove_min(), remove_min()?```
#
# **A:**
#
# D
#
# J
#
# B
#
# A
#
# H
#
# L

# %% [markdown]
# ## Problem 2.
# Write a Python program to ﬁnd the diﬀerence between the largest element and the smallest element in a given a binary search tree.

# %%
def minValueNode(node):
    current = node
    while current.left is not None:
        current = current.left
        
    return current

def maxValueNode(node):
    current = node
    while current.right is not None:
        current = current.right
        
    return current

def bst_difference(root):
    if root is None:
        print("Binary tree is empty!")
    return maxValueNode(root).value - minValueNode(root).value

# %%
from binarytree import build, Node
values = [8, 3, 10, 1, 6, None, 14, None, None, 4, 7, None, None, 13]
root = build(values)
print(bst_difference(root))
# Out:
# 13

# %% [markdown]
# ## Problem 3.
# Insert, into a binary search tree shown below, entries with keys 30, 40, 24, 58, 48, 26, 11, 13 (in this order). What will the BST look like?

# %%
import requests
import IPython.display as Disp
url = 'https://s3.us-west-2.amazonaws.com/secure.notion-static.com/883e4fd8-c518-47f3-9d6a-ef76d711188f/IMG_A14183D4E7FE-1.jpeg?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAT73L2G45HQYIVMIQ%2F20191129%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20191129T140559Z&X-Amz-Expires=86400&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEIX%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLXdlc3QtMiJGMEQCIAOZSu8LDv%2FeS5D%2FFCmmOvXIO2kZcktT7zXN6cdRkQ78AiAbqQnjYpNnXWxRBoGrYy3bBN6A0geXjDZXvdvx78f0vyraAgi%2B%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDI3NDU2NzE0OTM3MCIMR7p9n%2F1AFTsKEwBOKq4CURzeT0f5lky4z3Ea%2FIR6rFw3qqdY5CPic9ytOw9AvJpxEOWWiLt%2BfhvT1lLABsusdZAHGTpUMUryMIU5o5ZtuCZFAk4zS8IGTvOgOpXWLeTyITsDPY73sGR7mttQUlSjqS0OtpNjETZgID2Sx%2BRWruVNSsGM5r6mYWdq8mWqv2crz7%2B2pnLa7TZ3ULbzv%2B4qz2PDDxTt6xwO4kBo%2BveMj%2Fqsb1JfElxPr5gA6T6vRcuj0aDmbnBcJ0Y%2F9JQ25tm74JFtkA8Y2DrfWLOf3m9vLuW5VU%2BMT3T7Sn3vMtxPdOTFYzv3ldJjDCtGSyJV9JkGi4PH%2BWirt1nCZj8zps6bIgADK3xiWudx4wSS6IU06zzEULx6O0SzOrObxqtm7fYgoe3M9yWa04hQdWWAzoswlpuE7wU6zwKX5OJWyXrc%2FriOjlu15w0EgsJGXibMp0NcHRmlZE0iaEsL1Vgqion4%2BF1tnFGeRIoeA7WkFyxodpa0PLe%2BGeSN%2BBsaMIMVtSNLlO8UKRu8vdWBAUBA8F2j6Ed8aAzjE5of61uIqIwQ8LZMyZtOz4Ka7cR2X3DkJnAGOMASHVWmRXU6Fy8EaaXEpCICQSdvfR%2BfRM4FlRjZOMDbrbVGy1obJbjz5WNLF2aPWt%2BSJPzWqRS%2FkQxxX55ILT0qCVrYZWUqz8ECSVQwkx1Bb7%2B0AIiD1I54yvDrDO1oQ4SZVSqNZJZUrD1wkU%2FqHXfZTFw2yLmaugzW8uCGk7ukOQ7