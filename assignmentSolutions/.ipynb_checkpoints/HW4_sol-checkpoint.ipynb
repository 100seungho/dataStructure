# %%
# Problem 1

# %%
class Rectangle:
    def __init__(self,l,w):
        self.l = l
        self.w = w
    def rectangle_area(self):
        return self.l*self.w

# %%
R = Rectangle(10,20)

# %%
R.rectangle_area()
# Out:
# 200

# %%
# Problem 2

# %%
# %matplotlib notebook
from array import array
import sys
import matplotlib.pyplot as plt
N = []
size_list = []
size_array = []

for num in [2**k for k in range(10, 20)]:
    L = list(range(num))
    size_L = sys.getsizeof(L)

    A = array('i', L)
    size_A = sys.getsizeof(A)

    N.append(num)
    size_list.append(size_L)
    size_array.append(size_A)
    
plt.plot(N, size_array, 'o-')
plt.plot(N, size_list, 's-')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
myList = [76, 92.3, 'hello', True, 4, 76]

# %%
myList.append('apple')
myList.append(76)
print(myList)
# Out:
# [76, 92.3, 'hello', True, 4, 76, 'apple', 76]

# %%
myList.insert(3,'cat')
print(myList)
# Out:
# [76, 92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]

# %%
myList.insert(0,99)
print(myList)
# Out:
# [99, 76, 92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]

# %%
print(myList.index('hello'))
print(myList)
# Out:
# 3
# [99, 76, 92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]

# %%
print(myList.count(76))
print(myList)
# Out:
# 3
# [99, 76, 92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]

# %%
myList.pop(myList.index(True))
print(myList)
# Out:
# [99, 76, 92.3, 'hello', 'cat', 4, 76, 'apple', 76]

# %%
def fun(r, c, v):
    return r * [c * [v]]

# %%
fun(4,2,7)
# Out:
# [[7, 7], [7, 7], [7, 7], [7, 7]]

# %%
fun(3,1,'hello')
# Out:
# [['hello'], ['hello'], ['hello']]
